# %%
import pandas as pd

# %%
url = pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/refs/heads/master/concrete.csv")

# %%
url
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# ...

# %%
url.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
url.info
# Out:
# <bound method DataFrame.info of       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# ...

# %%
url.head()
# Out:
#    cement   slag  ash  water  superplastic  coarseagg  fineagg  age  strength
# 0   540.0    0.0  0.0  162.0           2.5     1040.0    676.0   28     79.99
# 1   540.0    0.0  0.0  162.0           2.5     1055.0    676.0   28     61.89
# 2   332.5  142.5  0.0  228.0           0.0      932.0    594.0  270     40.27
# 3   332.5  142.5  0.0  228.0           0.0      932.0    594.0  365     41.05
# 4   198.6  132.4  0.0  192.0           0.0      978.4    825.5  360     44.30

# %%
url.dtypes
# Out:
# cement          float64
# slag            float64
# ash             float64
# water           float64
# superplastic    float64
# coarseagg       float64
# fineagg         float64
# age               int64
# strength        float64
# dtype: object

# %%
url.tail
# Out:
# <bound method NDFrame.tail of       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# ...

# %%
import csv as pn

# %%
url.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %%
url.dtypes == "object"
# Out:
# cement          False
# slag            False
# ash             False
# water           False
# superplastic    False
# coarseagg       False
# fineagg         False
# age             False
# strength        False
# dtype: bool

# %%
url.dtypes[url.dtypes == "object"]
# Out:
# Series([], dtype: object)

# %%
# to get the index 
url.dtypes[url.dtypes == "object"].index
# Out:
# Index([], dtype='object')

# %%
url.dtypes[url.dtypes[url.dtypes == "object"].index]
# Out:
# Series([], dtype: object)

# %%
url.shape
# Out:
# (1030, 9)

# %%
url
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# ...

# %%
url["new columns"]= "pw skills"

# %%
url
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength new columns
# 0        79.99   pw skills
# 1        61.89   pw skills
# ...

# %%
url["New row"] =  1031

# %%
url
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength new columns  New row
# 0        79.99   pw skills     1031
# ...

# %%
url.shape
# Out:
# (1030, 10)

# %%
pd.Categorical(url['pclass'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 pd.Categorical(url['pclass'])
#
# ...

# %%
pd['pclass'].unque

# %%
# write a code csv file

import csv

student = [
    ['Name', 'Course', 'Fees'],
    ['Gunjan', 'Bsc', 10000],
    ['Gudiya', 'Bsc', 10000],
    ['Reshma', 'Bsc', 10000]
]

# stape 2
with open("student_Details.csv", 'w') as f:
    write = csv.writer(f)
    for row in student:
        write.writerow(row)

# %%
url[0:100]
# Out:
#     cement   slag  ash  water  superplastic  coarseagg  fineagg  age  strength
# 0    540.0    0.0  0.0  162.0           2.5     1040.0    676.0   28     79.99
# 1    540.0    0.0  0.0  162.0           2.5     1055.0    676.0   28     61.89
# 2    332.5  142.5  0.0  228.0           0.0      932.0    594.0  270     40.27
# 3    332.5  142.5  0.0  228.0           0.0      932.0    594.0  365     41.05
# 4    198.6  132.4  0.0  192.0           0.0      978.4    825.5  360     44.30
# ..     ...    ...  ...    ...           ...        ...      ...  ...       ...
# 95   425.0  106.3  0.0  153.5          16.5      852.1    887.1    7     49.20
# 96   425.0  106.3  0.0  151.4          18.6      936.0    803.7    7     46.80
# 97   375.0   93.8  0.0  126.6          23.4      852.1    992.6    7     45.70
# 98   475.0  118.8  0.0  181.1           8.9      852.1    781.5    7     55.60
# 99   469.0  117.2  0.0  137.8          32.2      852.1    840.5    7     54.90
#
# [100 rows x 9 columns]

# %%
df = url.shape
