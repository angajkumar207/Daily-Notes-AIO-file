# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/8217ecc82f6d11e8aac357d3aa5a9f362663c388/raw/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# ...

# %%
df

# %%
df.shape
# Out:
# (891, 11)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
df[0:100]
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# ..       ...     ...                                                ...
# 95         0       3                        Shorney, Mr. Charles Joseph
# 96         0       1                          Goldschmidt, Mr. George B
# 97         1       1                    Greenfield, Mr. William Bertram
# 98         1       2               Doling, Mrs. John T (Ada Julia Bone)
# 99         0       2                                  Kantor, Mr. Sinai
#
#        sex   age  sibsp  parch            ticket     fare    cabin embarked
# ...

# %%
df[0:100:2]
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 2          1       3                             Heikkinen, Miss. Laina
# 4          0       3                           Allen, Mr. William Henry
# 6          0       1                            McCarthy, Mr. Timothy J
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 12         0       3                     Saundercock, Mr. William Henry
# 14         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 16         0       3                               Rice, Master. Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20         0       2                               Fynney, Mr. Joseph J
# 22         1       3                        McGowan, Miss. Anna "Annie"
# ...

# %%
# how to access rows and columns bof dataframe >> implicit/integer, internal, indexing, emplicity, or name indexing.

# %%
# iloc
df.iloc[0:3] # starting count 0 and till 2 number so these are the iloc.
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# loc >> loc is used from name indexes / iloc used for integer indexing

df.loc[0:3]
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S

# %%
# loc ?? access rows 
df.loc[0:2,["name", "sex"]]
# Out:
#                                                 name     sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female

# %%
df.iloc[0:3, 3:5]
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0

# %%
list(df["name"][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df["name"][2:5]), index = ['a', 'b', 'c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
p = pd.Series(list(df["name"][5:8]))

# %%
p
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
"ANGAJ"+" Gunjan"
# Out:
# 'ANGAJ Gunjan'

# %%
# serise with different indexes and Dataframe can not be cancateneted using "+"
p + s
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# a    NaN
# b    NaN
# c    NaN
# dtype: object

# %%
# if you keep indexes some . than fo series cancatenation can happen.
s1 = pd.Series(list(df["name"][5:8]), index = ['a', 'b', 'c'])
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
p
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s1+s
# Out:
# a               Moran, Mr. JamesHeikkinen, Miss. Laina
# b    McCarthy, Mr. Timothy JFutrelle, Mrs. Jacques ...
# c    Palsson, Master. Gosta LeonardAllen, Mr. Willi...
# dtype: object

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.drop('passengerId', axis=1, errors='ignore')
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
df

# %%
df.drop(1, replace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.drop(1, replace = True)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'replace'

# %%
df.reset_index(drop=True)
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
df.set_index('name', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22380\1953162535.py in ?()
# ----> 1 df.set_index('name', inplace = True)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['name'] are in the columns"

# %%
df
# Out:
#                                                     survived  pclass     sex  \
# name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# survived            0
# pclass              3
# sex              male
# age              22.0
# sibsp               1
# parch               0
# ticket      A/5 21171
# fare             7.25
# cabin             NaN
# embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
# Create a dictionary and convert Dataframe.

d = {
    "Name1" : ["Angaj kumar", "Rohit kumar", "Abhishek Kumar"],
    "Class": ["BCA - 2nd Semester", "BCA - 3rd Semester", "BCA - 4th Semester"],
    "Roll no": [201, 202, 203]
}

# %%
d
# Out:
# {'Name1': ['Angaj kumar', 'Rohit kumar', 'Abhishek Kumar'],
#  'Class': ['BCA - 2nd Semester', 'BCA - 3rd Semester', 'BCA - 4th Semester'],
#  'Roll no': [201, 202, 203]}

# %%
pd.DataFrame(d) #this is my Data
# Out:
#             Name1               Class  Roll no
# 0     Angaj kumar  BCA - 2nd Semester      201
# 1     Rohit kumar  BCA - 3rd Semester      202
# 2  Abhishek Kumar  BCA - 4th Semester      203

# %%
s = {
    'Key1': [1, 2, 3],
    'Key2': [4, 5, 6],
    'key3': [7, 8, 9]
}

# %%
s
# Out:
# {'Key1': [1, 2, 3], 'Key2': [4, 5, 6], 'key3': [7, 8, 9]}

# %%
pd.DataFrame(s)
# Out:
#    Key1  Key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
p1 = pd.DataFrame(d)

# %%
p1
# Out:
#             Name1               Class  Roll no
# 0     Angaj kumar  BCA - 2nd Semester      201
# 1     Rohit kumar  BCA - 3rd Semester      202
# 2  Abhishek Kumar  BCA - 4th Semester      203

# %%
# imputation of missing value >> replacing missing values same values
# numeric Data >> mean and mediam >> outlier value treatment is done 
# categorical data >> mode
#

# %%
Data1 = {
    'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}
df1 = pd.DataFrame(Data1)

# %%
df1
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1['A'].mean()
# Out:
# 5.75

# %%
df1['A']
# Out:
# 0     1.0
# 1     2.0
# 2     NaN
# 3     4.0
# 4     5.0
# 5     NaN
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df1['A'].mean()
# Out:
# 5.75

# %%
df1['A'].median()
# Out:
# 6.0

# %%
df1['A'].fillna(df1['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df1
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1.fillna("add value")
# Out:
#            A          B
# 0        1.0  add value
# 1        2.0       11.0
# 2  add value       12.0
# 3        4.0       13.0
# 4        5.0  add value
# 5  add value       15.0
# 6        7.0       16.0
# 7        8.0  add value
# 8        9.0       18.0
# 9       10.0       19.0

# %%
# Q. What is the overage fare paid by the people who survised

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df['survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
df[df['survived'] == 1 ]
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..        ...     ...                                                ...
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
df[df['survived'] == 1]['fare'].mean()
# Out:
# 48.39540760233918

# %%
#what if i as average who survived? change fare to age.
#what if a ask max min/std age fare in one result
# group by

# %%
df.groupby('survived').mean(numeric_only = True)
# Out:
#             pclass        age     sibsp     parch       fare
# survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %% [markdown]
# ![image.png](attachment:e66b8d51-ad31-4a9a-9345-fb6f7a9644d3.png)![image.png]

# %%
df.groupby('survived').sum(numeric_only = True)
# Out:
#           pclass       age  sibsp  parch        fare
# survived
# 0           1390  12985.50    304    181  12142.7199
# 1            667   8219.67    162    159  16551.2294

# %%
df.groupby('survived').describe()
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         342.0  1.950292  0.863321  1.0  1.0  2.0  3.0  3.0  290.0
#
#                      ... parch        fare                             \
#                mean  ...   75%  max  count       mean        std  min
# survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.343690  ...   1.0  5.0  342.0  48.395408  66.596998  0.0
#
#
#               25%   50%   75%       max
# survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
import numpy as np
df.groupby(['survived'])[fare].age(min, 'max', 'mean', 'median', 'count', np.std, 'var' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 import numpy as np
# ----> 2 df.groupby(['survived'])[fare].age(min, 'max', 'mean', 'median', 'count', np.std, 'var' )
#
# NameError: name 'fare' is not defined

# %%
df.groupby(['sex', 'pclass'])['survived'].sum()
# Out:
# sex     pclass
# female  1         91
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: survived, dtype: int64

# %%
df.groupby(['sex', 'pclass'])['survived'].sum().to_frame()
# Out:
#                survived
# sex    pclass
# female 1             91
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['sex', 'pclass'])['survived'].sum().to_frame().reset_index()
# Out:
#       sex  pclass  survived
# 0  female       1        91
# 1  female       2        70
# 2  female       3        72
# 3    male       1        45
# 4    male       2        17
# 5    male       3        47

# %%
s = df.groupby('pclass').sum(numeric_noly = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 s = df.groupby('pclass').sum(numeric_noly = True)
#
# TypeError: GroupBy.sum() got an unexpected keyword argument 'numeric_noly'

# %% [markdown]
# https://youtu.be/NqbyBnx6e1o
