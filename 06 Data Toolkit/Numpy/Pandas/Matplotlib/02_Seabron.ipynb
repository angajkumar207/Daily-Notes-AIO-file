# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [raw]
# # Seaborn
# >> more attractive pots
# >> more options statistical pots
#
# # seaborn is a python visualizention labrary based on matplotlib. iot provides a high-lavel interface .for drowing attractive and informative statistical graphics

# %%
df = sns.get_dataset_names()

# %%
df
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, color = 'red')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'smoker')
# insigt >> customer who smokedgave the highest tip

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'size') # hue gives the dioffrent color shades

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style = 'size') # style gives the different representation of a columns value

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style = 'smoker', hue = 'time')

# %%
# relplot for mking a line plot >> genreting a data 
# line plot >> to understand the trnd in data in . a time columns/squence is generally is there

time =  np.arange(500)
value = np.random.randn(500).cumsum()

# %%
value

# %%
df = pd.DataFrame({"time": time, "value": value})

# %%
df
# Out:
#      time     value
# 0       0  0.462956
# 1       1 -0.417903
# 2       2  0.416331
# 3       3 -0.678562
# 4       4 -0.174039
# ..    ...       ...
# 495   495 -0.035524
# 496   496 -2.213105
# 497   497 -2.226317
# 498   498 -2.377446
# 499   499 -2.418327
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
df = sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, color = 'red', marker = 'o', linestyle = "--")

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, ci = 'sd', estimator = None)

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, hue = 'event')

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, hue = 'event', style = "region")

# %%
sns.relplot(x = 'timepoint', y = "signal", kind = 'line', data = fmri, hue = 'event', style = "region", markers = True)

# %%
tip = sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# two subplots best on a columns 
sns.relplot(x = 'total_bill', y = 'tip', hue = "smoker", data = tip, col = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = "smoker", data = tip, col = 'size')

# %%
# categprical data plot

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#plopt between data and total bill, day is categorical data columns
sns.catplot(x = "day", y = "total_bill", data = tip)

# %%
# insights >> many people arrives on weekend as compared to weekdays
sns.catplot(x = "day", y = "total_bill", data = tip)

# %%
# categorical data column
# in cat plot few datapoint are overlopping >> to see it sparately use sarwm plot 
sns.catplot(x = "day", y = "total_bill", data = tip, kind = 'swarm')

# %%
# boxplot to see outliers
sns.catplot(x = 'day', y = 'total_bill', data = tip, kind = 'box',showfliers=False, palette='Set2')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tip, kind = 'violin')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tip, kind = 'boxen')

# %%
c
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tip.total_bill, y = tip.tip)

# %%
# joint plot >> understsand relationship and also distrbutation of two varibles
sns.jointplot(x = tip.total_bill, y = tip.tip, kind = "reg")

# %%
# carnel density estimatar, cantour/metrological 
sns.jointplot(x = tip.total_bill, y = tip.tip, kind = "kde")

# %%
sns.pairplot(tip) # make plot scatter plot with respact to all noemrical columns

# %%
sns.pairplot(tip, hue = 'smoker')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tip)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tip, height = 15)
